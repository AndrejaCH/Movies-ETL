# %%
#Import dependencies
import json
import pandas as pd
import numpy as np

# %%
# THE PROCESS OF ---- EXCTRACTING ----- 
#ALSO CHECK THE IMPORT AND DATA

# %%
#Create a variable with the exact path to the directory where data is stored.
#If you want to open a file in directory, use f-string and pass the variable: f'{file_dir}filename'
file_dir = 'C:/Users/sfand/Desktop/python_work/BC'

# %%
#Load the JSON into a List of Dictionaries.
#Using the "with" statement to open the Wikipedia JSON file to be read into the variable file, 
#and use json.load() to save the data to a new variable.
#Since JSON is NOT a flat file, we cannot just read it into pd data frame (technically we could, yet would be messy!)
with open(f'{file_dir}/wikipedia-movies.json', mode='r') as file:
    wiki_movies_raw = json.load(file)
    
#Now read this file into a dataframe (the code below is commented out, and appears later, 
#becaue to follow the sequence of the module) and inspect the data frame:
#wiki_movies_df = pd.DataFrame(wiki_movies_raw)
#wiki_movies_df.head() + see the code below for additional cheching the tables.

# %%
#Inspect the data before moving on (lenght, how data looks like, etc).
#Since wiki_movies_raw is a (JSON) list use index slicing
len(wiki_movies_raw) #Check the lenght
wiki_movies_raw[:5] #Check first 5, 
wiki_movies_raw[-5:] #Check last 5
wiki_movies_raw[3600:3605] #Check somewhere in the middle
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Benji:_Off_the_Leash!',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0315273/',
#   'title': 'Benji: Off the Leash!',
#   'Directed by': 'Joe Camp',
#   'Written by': 'Joe Camp',
#   'Starring': ['Benji', 'Nick Whitaker', 'Shaggy', 'Gypsy the Cockatoo'],
#   'Music by': 'Antonio di Lorenzo',
#   'Productioncompany ': 'Mulberry Square Productions',
#   'Distributed by': 'Mulberry Square Productions',
#   'Release date': ['March 26, 2004', '(', '2004-03-26', ')'],
#   'Running time': '97 min',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$3,817,362'},
#  {'url': 'https://en.wikipedia.org/wiki/The_Best_Thief_in_the_World',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0389796/',
#   'title': 'The Best Thief in the World',
#   'Directed by': 'Jacob Kornbluth',
#   'Produced by': ['Tim Perrell', 'Nicola Usborne'],
#   'Written by': 'Jacob Kornbluth',
# ...

# %%
#Load and read Keggle data. Since those are already in flat formats we can directly read it into pd data frame.
kaggle_metadata = pd.read_csv(f'{file_dir}/movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'{file_dir}/ratings.csv')

# %%
#Inspect the data before moving on.
#Since we read those files into data frame we inspect data with Pands commands.
kaggle_metadata.sample(n=3) #Using sample - will return 3 random samples from a data frame
ratings.head()
ratings.tail()
# Out:
#           userId  movieId  rating   timestamp
# 26024284  270896    58559     5.0  1257031564
# 26024285  270896    60069     5.0  1257032032
# 26024286  270896    63082     4.5  1257031764
# 26024287  270896    64957     4.5  1257033990
# 26024288  270896    71878     2.0  1257031858

# %%
# THE PROCESS OF ---- TRANSFORMING ----- DATA (largely spent on data CLEANING) | INSPECT | PLAN | EXECUTE

# %%
#INITIAL INVESTIGATION
#Convert the json file (that is list of dictionaries in this case) directly into data frame!
wiki_movies_df = pd.DataFrame(wiki_movies_raw)
#And check first few lines
wiki_movies_df.head()
# Out:
#                                                  url    year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990.0
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990.0
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990.0
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990.0
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990.0
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# ...

# %%
#ADDITIONAL INVESTIGATION
#Exporting data to CSV file: IS THIS SOMETHING WE COULD DO? Possible - try slicing instead!
#wiki_movies_df.to_csv("wiki_movies_inspect.csv")

#ILOC slicing
#wiki_loc_test = wiki_movies_df.iloc[:, -12:-1]

#LOC slicing 
#wiki_loc_test1 = wiki_movies_df.loc[:, "imdb_link":"Produced by"]
#wiki_loc_test1.head()

# %%
#Check the columns. List all the columns. You can use (wiki_movies_df.columns), but if too many columns - 
#Convert wiki_movies_df.columns to list with the following command to list all the columns:
wiki_movies_df.columns.tolist()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Directed by',
#  'Produced by',
#  'Screenplay by',
#  'Story by',
#  'Based on',
#  'Starring',
#  'Narrated by',
#  'Music by',
#  'Cinematography',
#  'Edited by',
#  'Productioncompany ',
#  'Distributed by',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Written by',
#  'Genre',
#  'Theme music composer',
#  'Country of origin',
#  'Original language(s)',
#  'Producer(s)',
#  'Editor(s)',
#  'Production company(s)',
#  'Original network',
#  'Original release',
#  'Productioncompanies ',
#  'Executive producer(s)',
#  'Production location(s)',
#  'Distributor',
#  'Picture format',
#  'Audio format',
#  'Voices of',
#  'Followed by',
#  'Composer(s)',
#  'Created by',
#  'Also known as',
#  'Opening theme',
#  'No. of episodes',
#  'Preceded by',
#  'Author',
#  'Publisher',
#  'Publication date',
#  'Media type',
#  'Pages',
#  'ISBN',
#  'OCLC',
#  'LC Class',
# ...

# %%
#GET RID OF THE DATA YOU DON'T WANT RIGHT AWAY: for example - no movies w/o directorm & imbd link and no episodes!
#-------------------------------------------------------------------------------------------------------------------------
#NONDESTRUCTIVE EDITS: keep your raw data in one variable, and the cleaned data in another variable.
#Using nondestructive edits helps determine the origin of errors.
#-------------------------------------------------------------------------------------------------------------------------

#Using list comprehension with condition: Making selection on data - keep only ones who has Director and imdb_link and
#not the one that are episodes - we want only movies!!.
#Condition is: if('Director' in movie or 'Directed by' in movie) and 'imdb_link' in movie and 'No. of episodes' not in movie
#List comprehension + condition as follows:
wiki_movies = [movie for movie in wiki_movies_raw
               if ('Director' in movie or 'Directed by' in movie)
                   and 'imdb_link' in movie
                   and 'No. of episodes' not in movie]
len(wiki_movies)
# Out:
# 7076

# %%
#Make a dataframe from the cleaner wiki_movies "and the bad columns never get imported in."
#wiki_movies_raw = still untouched, since we used new variable.
wiki_movies_df = pd.DataFrame(wiki_movies)
wiki_movies_df.head(1)
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
#
#     Directed by                 Produced by  \
# 0  Renny Harlin  [Steve Perry, Joel Silver]
#
#                                 Screenplay by                     Story by  \
# 0  [David Arnott, James Cappe, Daniel Waters]  [David Arnott, James Cappe]
#
#                       Based on  \
# 0  [Characters, by Rex Weiner]
#
#                                             Starring  ... Hepburn Literally  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  ...     NaN       NaN
#
#   Cantonese Chinese Yiddish Arabic Romanized Russian Hebrew Polish
# 0       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
#
# [1 rows x 75 columns]

# %%
#Add here all the code for inspecting languages - module 8.3.5

# %%
#Clean Languages: Columns for different languages - combine them into one dictionary.
def clean_movie(movie):
    movie = dict(movie) #create a non-destructive copy
    alt_titles = {}
    for key in ['Also known as','Arabic','Cantonese','Chinese','French',
                'Hangul','Hebrew','Hepburn','Japanese','Literally',
                'Mandarin','McCune–Reischauer','Original title','Polish',
                'Revised Romanization','Romanized','Russian',
                'Simplified','Traditional','Yiddish']:
        if key in movie:
            alt_titles[key] = movie[key]
            movie.pop(key)
    if len(alt_titles) > 0:
        movie['alt_titles'] = alt_titles

    return movie

# %%
#Apply function clean_movie to every movie in the list. - is this ok?
#We can make a list of cleaned movies with a list comprehension.
clean_movies = [clean_movie(movie) for movie in wiki_movies]

# %%
#Read in the clean movies dataframe
wiki_movies_df = pd.DataFrame(clean_movies)
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Adaptation by',
#  'Animation by',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Country of origin',
#  'Created by',
#  'Directed by',
#  'Director',
#  'Distributed by',
#  'Distributor',
#  'Edited by',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'Genre',
#  'Label',
#  'Language',
#  'Length',
#  'Music by',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Original release',
#  'Picture format',
#  'Preceded by',
#  'Produced by',
#  'Producer',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Productioncompanies ',
#  'Productioncompany ',
#  'Recorded',
#  'Release date',
#  'Released',
#  'Running time',
#  'Screen story by',
#  'Screenplay by',
#  'Starring',
#  'Story by',
#  'Suggested by',
#  'Theme music composer',
#  'Venue',
#  'Voices of',
#  'Written by',
#  'alt_titles',
#  'imdb_link',
#  'title',
# ...

# %%
#Testing the def clean_movies
test = wiki_movies_df['alt_titles'].value_counts()
test
# Out:
# {'Mandarin': 'Xǐyàn', 'Traditional': '喜宴'}                                                                                                                                                                                                                                                                                                                    1
# {'Chinese': '摇滚藏獒'}                                                                                                                                                                                                                                                                                                                                           1
# ...

# %%
try:
    wiki_movies_df['imdb_id'] = wiki_movies_df['imdb_link'].str.extract(r'(tt\d{7})')
    print(len(wiki_movies_df))
    wiki_movies_df.drop_duplicates(subset='imdb_id', inplace=True)
    print(len(wiki_movies_df))
except (ValueError, IndexError):
    print("test")
# Out:
# 7076
# 7033

# %%
wiki_movies_df.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# 1         James Foley  [Ric Kidney, Robert Redlin]
# ...
